# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 5C52-1ED8
#
#  Directory of C:\Users\vvijayan\Desktop\benthamiana and araport\araport\GPI
#
# 05/12/2025  02:32 PM    <DIR>          .
# 05/12/2025  02:32 PM    <DIR>          ..
# 05/12/2025  02:32 PM    <DIR>          .ipynb_checkpoints
# 05/09/2025  12:21 PM            16,538 extract_GPI.ipynb
# 05/12/2025  02:27 PM            62,395 output_protein_type.txt
#                2 File(s)         78,933 bytes
#                3 Dir(s)  102,893,158,400 bytes free

# %%
import pandas as pd
df= pd.read_csv('output_protein_type.txt' , sep='\t', skiprows=1)
df
# Out:
#              # ID  Seq-length Pred. GPI-Anchored Omega-site pos.  Likelihood  \
# 0     AT1G01650.1         540   Not GPI-Anchored               -       0.972
# 1     AT4G18370.3         240   Not GPI-Anchored               -       0.989
# 2     AT4G18370.1         323   Not GPI-Anchored               -       0.945
# 3     AT4G17895.1         695   Not GPI-Anchored               -       0.995
# 4     AT4G17860.1         356   Not GPI-Anchored               -       0.994
# ...           ...         ...                ...             ...         ...
# 1443  AT2G24000.2         401   Not GPI-Anchored               -       0.968
# 1444  AT2G24000.1         464   Not GPI-Anchored               -       0.968
# 1445  AT2G23970.1         251   Not GPI-Anchored               -       0.996
# 1446  AT2G23960.2         217   Not GPI-Anchored               -       0.992
# 1447  AT1G71230.2          87   Not GPI-Anchored               -       0.990
#
#      Amino-acid
# 0             *
# ...

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 5C52-1ED8
#
#  Directory of C:\Users\vvijayan\Desktop\benthamiana and araport\araport\GPI
#
# 05/12/2025  02:36 PM    <DIR>          .
# 05/12/2025  02:32 PM    <DIR>          ..
# 05/12/2025  02:32 PM    <DIR>          .ipynb_checkpoints
# 05/12/2025  02:14 PM            65,997 araport_family.xlsx
# 05/12/2025  02:34 PM             9,954 extract_GPI.ipynb
# 05/12/2025  02:27 PM            62,395 output_protein_type.txt
#                3 File(s)        138,346 bytes
#                3 Dir(s)  102,885,527,552 bytes free

# %%
import pandas as pd

# Replace 'your_file.xlsx' with your actual filename
file_path = 'araport_family.xlsx'

# Load the Excel file
df2 = pd.read_excel(file_path)

# Display the first few rows
df2.head()
# Out:
#        Gene ID                           Localizations  Predicted TMRs  \
# 0  AT1G01650.1                        Lysosome/Vacuole               9
# 1  AT1G01650.2  Endoplasmic reticulum|Lysosome/Vacuole               9
# 2  AT1G01650.3  Endoplasmic reticulum|Lysosome/Vacuole               9
# 3  AT1G01650.4  Endoplasmic reticulum|Lysosome/Vacuole               9
# 4  AT1G01900.1                           Extracellular               0
#
#   Prediction  matched    Family Extracted_Alphabet_Family
# 0         SP  PF04258  nan/A22B                         N
# 1      OTHER  PF04258  nan/A22B                         N
# 2      OTHER  PF04258  nan/A22B                         N
# 3      OTHER  PF04258  nan/A22B                         N
# 4         SP  PF00082    S8/S8A                         S

# %%
# Create the mapping using the correct column name
gpi_mapping = df.set_index('# ID')['Pred. GPI-Anchored']

# Map the values to df2['Gene ID']
df2['Pred. GPI-Anchored'] = df2['Gene ID'].map(gpi_mapping)

# %%
# Save df2 to an Excel file
df2.to_excel('araport_with_GPI.xlsx', index=False)
